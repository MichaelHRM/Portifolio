# %% [markdown]
# # Processamento de dados usando o Databricks - PySpark
# * Este notebook visa fazer o processamento de dados usando o PySpark.
# * Neste laboratório serão utilizados 5 arquivos que simbolizam as vendas de um site de *e-commerce*, os arquivos estão no formato parquet(formato padrão do Spark).
# * No final do processamento será gerado um único arquivo parquet contendo as transformações.

# %%
# Importando as bibliotecas que serão usadas no laboratorio.

from pyspark.sql import *
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %% [markdown]
# # Importando os arquivos parquet para processamento

# %%
# Tipo do arquivos
file_type = "parquet"

# Path dos arquivos
file_location1 = "/FileStore/tables/Clientes.parquet"
file_location2 = "/FileStore/tables/ItensVendas.parquet"
file_location3 = "/FileStore/tables/Produtos.parquet"
file_location4 = "/FileStore/tables/Vendas.parquet"
file_location5 = "/FileStore/tables/Vendedores.parquet"

arq_Clientes =  spark \
                .read.format(file_type)\
                .option("inferSchema","True")\
                .option("header", "True")\
                .parquet(file_location1)

arq_ItensVendas =  spark \
                .read.format(file_type)\
                .option("inferSchema","True")\
                .option("header", "True")\
                .parquet(file_location2)

arq_Produtos =   spark \
                .read.format(file_type)\
                .option("inferSchema","True")\
                .option("header", "True")\
                .parquet(file_location3)

arq_Vendas =   spark \
                .read.format(file_type)\
                .option("inferSchema","True")\
                .option("header", "True")\
                .parquet(file_location4)

arq_Vendedores =  spark \
                .read.format(file_type)\
                .option("inferSchema","True")\
                .option("header", "True")\
                .parquet(file_location5)

# Modificando o nome das colunas do dataframe  ** arq_Vendas **
arq_Vendas = arq_Vendas.withColumnRenamed("VendasID", "IdVendasID") \
                       .withColumnRenamed("VendedorID", "IdVendedor") \
                       .withColumnRenamed("ClienteID", "IdCliente")

# Modificando o nome de uma coluna do dataframe  ** arq_ItensVendas **
arq_ItensVendas = arq_ItensVendas.withColumnRenamed("ProdutoID", "IdProduto")

# %% [markdown]
# # Conhecendo os arquivos
# * Inspecionando o schema de cada arquivo.

# %%
# %fs ls /FileStore/tables/Clientes.parquet
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Clientes.parquet</td><td>Clientes.parquet</td><td>9311</td><td>1654426456000</td></tr></tbody></table></div>

# %%
print("Clientes - ",arq_Clientes.take)
print("ItensVendas - ",arq_ItensVendas.take)
print("Produtos - ",arq_Produtos.take)
print("Vendas - ",arq_Vendas.take)
print("Vendedores - ",arq_Vendedores.take)
# Out:
# Clientes -  <bound method DataFrame.take of DataFrame[ClienteID: bigint, Cliente: string, Estado: string, Genero: string, Status: string]>
# ItensVendas -  <bound method DataFrame.take of DataFrame[IdProduto: bigint, VendasID: bigint, Quantidade: bigint, ValorUnitario: double, ValorTotal: double, Desconto: string, TotalComDesconto: double]>
# Produtos -  <bound method DataFrame.take of DataFrame[ProdutoID: bigint, Produto: string, Preco: string]>
# Vendas -  <bound method DataFrame.take of DataFrame[IdVendasID: bigint, IdVendedor: bigint, IdCliente: bigint, Data: string, Total: double]>
# Vendedores -  <bound method DataFrame.take of DataFrame[VendedorID: bigint, Vendedor: string]>

# %% [markdown]
# #Gerando cache dos DataFrames
# O objetivo é facilitar o processamento uma vez que estaremos realizando algumas operações neles.

# %%
arq_Clientes.cache()
arq_Produtos.cache()
arq_Vendas.cache()
arq_Vendedores.cache()
# Out:
# Out[105]: DataFrame[VendedorID: bigint, Vendedor: string]

# %% [markdown]
# #Verificando a quantidade de registros de cada arquivo

# %%
print("Qte. de Linhas - Clientes #", arq_Clientes.count())
print("Qte. de Linhas - Prosdutos #",arq_Produtos.count())
print("Qte. de Linhas - Vendas #",arq_Vendas.count())
print("Qte. de Linhas - Vendedores #",arq_Vendedores.count())
print("Qte. de Linhas - Produtos #",arq_ItensVendas.count())
# Out:
# Qte. de Linhas - Clientes # 250
# Qte. de Linhas - Prosdutos # 10
# Qte. de Linhas - Vendas # 400
# Qte. de Linhas - Vendedores # 10
# Qte. de Linhas - Produtos # 940

# %% [markdown]
# #Display de 5 linhas de cada DataFrame

# %%
display(arq_Clientes.limit(5))
display(arq_Produtos.limit(5))
display(arq_Vendas.limit(5))
display(arq_Vendedores.limit(5))
display(arq_ItensVendas.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ClienteID</th><th>Cliente</th><th>Estado</th><th>Genero</th><th>Status</th></tr></thead><tbody><tr><td>1</td><td>Adelina Buenaventura</td><td>RJ</td><td>M</td><td>Silver</td></tr><tr><td>2</td><td>Adelino Gago</td><td>RJ</td><td>M</td><td>Silver</td></tr><tr><td>3</td><td>Adolfo Patrício</td><td>PE</td><td>M</td><td>Silver</td></tr><tr><td>4</td><td>Adriana Guedelha</td><td>RO</td><td>F</td><td>Platinum</td></tr><tr><td>5</td><td>Adélio Lisboa</td><td>SE</td><td>M</td><td>Silver</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProdutoID</th><th>Produto</th><th>Preco</th></tr></thead><tbody><tr><td>1</td><td>Bicicleta Aro 29 Mountain Bike Endorphine 6.3 - 24 Marchas - Shimano - Alumínio</td><td>8.852,00 </td></tr><tr><td>2</td><td>Bicicleta Altools Stroll Aro 26 Freio À Disco 21 Marchas</td><td>9.201,00 </td></tr><tr><td>3</td><td>Bicicleta Gts Advanced 1.0 Aro 29 Freio Disco Câmbio Traseiro Shimano 24 Marchas</td><td>4.255,00 </td></tr><tr><td>4</td><td>Bicicleta Trinc Câmbios Shimano Aro 29 Freio A Disco 24v</td><td>7.658,00 </td></tr><tr><td>5</td><td>Bicicleta Gometws Endorphine 7.3 - Shimano Alumínio Aro 29 - 24 Marchas</td><td>2.966,00 </td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IdVendasID</th><th>IdVendedor</th><th>IdCliente</th><th>Data</th><th>Total</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>91</td><td>1/1/2019</td><td>8053.6</td></tr><tr><td>2</td><td>6</td><td>185</td><td>1/1/2020</td><td>150.4</td></tr><tr><td>3</td><td>7</td><td>31</td><td>2/1/2020</td><td>6087.0</td></tr><tr><td>4</td><td>5</td><td>31</td><td>2/1/2019</td><td>13828.6</td></tr><tr><td>5</td><td>5</td><td>31</td><td>3/1/2018</td><td>26096.66</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendedorID</th><th>Vendedor</th></tr></thead><tbody><tr><td>1</td><td>Armando Lago</td></tr><tr><td>2</td><td>Capitolino Bahía</td></tr><tr><td>3</td><td>Daniel Pirajá</td></tr><tr><td>4</td><td>Godo Capiperibe</td></tr><tr><td>5</td><td>Hélio Liberato</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IdProduto</th><th>VendasID</th><th>Quantidade</th><th>ValorUnitario</th><th>ValorTotal</th><th>Desconto</th><th>TotalComDesconto</th></tr></thead><tbody><tr><td>2</td><td>400</td><td>2</td><td>9201.0</td><td>18402.0</td><td>6256,68</td><td>12145.32</td></tr><tr><td>2</td><td>385</td><td>2</td><td>9201.0</td><td>18402.0</td><td>5704,62</td><td>12697.38</td></tr><tr><td>4</td><td>395</td><td>2</td><td>6892.2</td><td>13784.4</td><td>5100,23</td><td>8684.17</td></tr><tr><td>4</td><td>367</td><td>2</td><td>6509.3</td><td>13018.6</td><td>4816,88</td><td>8201.72</td></tr><tr><td>2</td><td>380</td><td>2</td><td>7038.77</td><td>14077.54</td><td>4364,04</td><td>9713.5</td></tr></tbody></table></div>

# %% [markdown]
# #Fazendo a união dos arquivos
# * Objetivo dos joins é unir todas as tabelas auxiliares gerando somente uma tabela Fato.

# %%
ft_vendas = arq_Vendas.join(arq_Clientes,    arq_Vendas.IdVendasID ==  arq_Clientes.ClienteID , "inner")   \
                      .join(arq_Vendedores,  arq_Vendas.IdVendedor == arq_Vendedores.VendedorID , "inner") \
                      .join(arq_ItensVendas, arq_Vendas.IdVendasID == arq_ItensVendas.VendasID , "inner")   \
                      .join(arq_Produtos,    arq_ItensVendas.IdProduto == arq_Produtos.ProdutoID , "inner")

# %%
# Visualizando o DataFrame após união das tabelas auxiliares

ft_vendas.show(5)
# Out:
# +----------+----------+---------+--------+--------+---------+--------------------+------+------+--------+----------+----------------+---------+--------+----------+-------------+----------+--------+----------------+---------+--------------------+---------+
# |IdVendasID|IdVendedor|IdCliente|    Data|   Total|ClienteID|             Cliente|Estado|Genero|  Status|VendedorID|        Vendedor|IdProduto|VendasID|Quantidade|ValorUnitario|ValorTotal|Desconto|TotalComDesconto|ProdutoID|             Produto|    Preco|
# +----------+----------+---------+--------+--------+---------+--------------------+------+------+--------+----------+----------------+---------+--------+----------+-------------+----------+--------+----------------+---------+--------------------+---------+
# |         1|         1|       91|1/1/2019|  8053.6|        1|Adelina Buenaventura|    RJ|     M|  Silver|         1|    Armando Lago|        2|       1|         1|      7820.85|   7820.85|     -  |         7820.85|        2|Bicicleta Altools...|9.201,00 |
# |         1|         1|       91|1/1/2019|  8053.6|        1|Adelina Buenaventura|    RJ|     M|  Silver|         1|    Armando Lago|        9|       1|         1|        97.75|     97.75|    0,98|           96.77|        9|Bermuda Predactor...|  115,00 |
# |         1|         1|       91|1/1/2019|  8053.6|        1|Adelina Buenaventura|    RJ|     M|  Silver|         1|    Armando Lago|       10|       1|         1|        135.0|     135.0|    1,35|          133.65|       10|Camiseta Predacto...|  135,00 |
# |         2|         6|      185|1/1/2020|   150.4|        2|        Adelino Gago|    RJ|     M|  Silver|         6|   Iberê Lacerda|        8|       2|         1|        150.4|     150.4|    1,50|           148.9|        8|Luva De Ciclismo ...|  188,00 |
# |         3|         7|       31|2/1/2020|  6087.0|        3|     Adolfo Patrício|    PE|     M|  Silver|         7|Jéssica Castelão|        7|       3|         1|        155.0|     155.0|     -  |           155.0|        7|Capacete Gometws ...|  155,00 |
# |         3|         7|       31|2/1/2020|  6087.0|        3|     Adolfo Patrício|    PE|     M|  Silver|         7|Jéssica Castelão|        5|       3|         2|       2966.0|    5932.0|     -  |          5932.0|        5|Bicicleta Gometws...|2.966,00 |
# |         4|         5|       31|2/1/2019| 13828.6|        4|    Adriana Guedelha|    RO|     F|Platinum|         5|  Hélio Liberato|        2|       4|         1|      7820.85|   7820.85|     -  |         7820.85|        2|Bicicleta Altools...|9.201,00 |
# |         4|         5|       31|2/1/2019| 13828.6|        4|    Adriana Guedelha|    RO|     F|Platinum|         5|  Hélio Liberato|        9|       4|         1|        97.75|     97.75|    0,98|           96.77|        9|Bermuda Predactor...|  115,00 |
# |         4|         5|       31|2/1/2019| 13828.6|        4|    Adriana Guedelha|    RO|     F|Platinum|         5|  Hélio Liberato|        6|       4|         2|       2955.0|    5910.0|   59,10|          5850.9|        6|Bicicleta Gometws...|2.955,00 |
# |         5|         5|       31|3/1/2018|26096.66|        5|       Adélio Lisboa|    SE|     M|  Silver|         5|  Hélio Liberato|        6|       5|         1|       2955.0|    2955.0|     -  |          2955.0|        6|Bicicleta Gometws...|2.955,00 |
# |         5|         5|       31|3/1/2018|26096.66|        5|       Adélio Lisboa|    SE|     M|  Silver|         5|  Hélio Liberato|        4|       5|         1|       7658.0|    7658.0|     -  |          7658.0|        4|Bicicleta Trinc C...|7.658,00 |
# |         5|         5|       31|3/1/2018|26096.66|        5|       Adélio Lisboa|    SE|     M|  Silver|         5|  Hélio Liberato|        1|       5|         1|       8852.0|    8852.0|     -  |          8852.0|        1|Bicicleta Aro 29 ...|8.852,00 |
# |         5|         5|       31|3/1/2018|26096.66|        5|       Adélio Lisboa|    SE|     M|  Silver|         5|  Hélio Liberato|       10|       5|         1|        121.5|     121.5|    1,22|          120.29|       10|Camiseta Predacto...|  135,00 |
# |         5|         5|       31|3/1/2018|26096.66|        5|       Adélio Lisboa|    SE|     M|  Silver|         5|  Hélio Liberato|        3|       5|         2|      3255.08|   6510.16|   65,10|         6445.06|        3|Bicicleta Gts Adv...|4.255,00 |
# |         6|         5|       31|4/1/2020| 18402.0|        6|       Adérito Bahía|    MA|     M|  Silver|         5|  Hélio Liberato|        2|       6|         2|       9201.0|   18402.0|  184,02|        18217.98|        2|Bicicleta Altools...|9.201,00 |
# |         7|         5|       31|6/1/2019|  7524.2|        7|       Aida Dorneles|    RN|     F|  Silver|         5|  Hélio Liberato|        1|       7|         1|       7524.2|    7524.2|     -  |          7524.2|        1|Bicicleta Aro 29 ...|8.852,00 |
# |         8|         5|      186|6/1/2019| 12036.6|        8|   Alarico Quinterno|    AC|     M|  Silver|         5|  Hélio Liberato|        8|       8|         2|        188.0|     376.0|     -  |           376.0|        8|Luva De Ciclismo ...|  188,00 |
# |         8|         5|      186|6/1/2019| 12036.6|        8|   Alarico Quinterno|    AC|     M|  Silver|         5|  Hélio Liberato|        3|       8|         1|      3616.75|   3616.75|     -  |         3616.75|        3|Bicicleta Gts Adv...|4.255,00 |
# |         8|         5|      186|6/1/2019| 12036.6|        8|   Alarico Quinterno|    AC|     M|  Silver|         5|  Hélio Liberato|       10|       8|         1|        108.0|     108.0|    1,08|          106.92|       10|Camiseta Predacto...|  135,00 |
# |         8|         5|      186|6/1/2019| 12036.6|        8|   Alarico Quinterno|    AC|     M|  Silver|         5|  Hélio Liberato|        9|       8|         1|        115.0|     115.0|    1,15|          113.85|        9|Bermuda Predactor...|  115,00 |
# +----------+----------+---------+--------+--------+---------+--------------------+------+------+--------+----------+----------------+---------+--------+----------+-------------+----------+--------+----------------+---------+--------------------+---------+
# only showing top 20 rows

# %% [markdown]
# #Ordenação de algumas colunas para melhorar a visualização
# * Nesta etapa foi selecionado apenas algumas colunas da união de todos os arquivos, aplicando a ordenação Descendente.

# %%
# Gerando um novo DataFrame com a seleção de algumas colunas

ft_vendas_ordenado = ft_vendas.select("VendasID","Data","VendedorID","Vendedor","ClienteID","Cliente","Status", \
                                      "ProdutoID","Produto","Quantidade","ValorUnitario","ValorTotal","Desconto","TotalComDesconto") \
                                      .orderBy(desc("ValorTotal"))

# Visualizando 10 linhas do novo DataFrame
ft_vendas_ordenado.show(10)
# Out:
# +--------+---------+----------+----------------+---------+--------------------+------+---------+--------------------+----------+-------------+----------+--------+----------------+
# |VendasID|     Data|VendedorID|        Vendedor|ClienteID|             Cliente|Status|ProdutoID|             Produto|Quantidade|ValorUnitario|ValorTotal|Desconto|TotalComDesconto|
# +--------+---------+----------+----------------+---------+--------------------+------+---------+--------------------+----------+-------------+----------+--------+----------------+
# |     156|17/5/2019|         7|Jéssica Castelão|      156|   Faustino Maranhão|Silver|        2|Bicicleta Altools...|         2|       9201.0|   18402.0| 1104,12|        17297.88|
# |     173| 4/6/2020|         5|  Hélio Liberato|      173|   Florinda Assunção|Silver|        2|Bicicleta Altools...|         2|       9201.0|   18402.0| 1840,20|         16561.8|
# |     110|10/4/2019|         4| Godo Capiperibe|      110|Deolinda Castelbr...|Silver|        2|Bicicleta Altools...|         2|       9201.0|   18402.0|  920,10|         17481.9|
# |       6| 4/1/2020|         5|  Hélio Liberato|        6|       Adérito Bahía|Silver|        2|Bicicleta Altools...|         2|       9201.0|   18402.0|  184,02|        18217.98|
# |      98|23/3/2020|        10|  Tobias Furtado|       98|      Cássia Queiroz|Silver|        1|Bicicleta Aro 29 ...|         2|       8852.0|   17704.0| 1062,24|        16641.76|
# |      69|24/2/2019|         7|Jéssica Castelão|       69|    Catarina Bairros|Silver|        1|Bicicleta Aro 29 ...|         2|       8852.0|   17704.0|     -  |         17704.0|
# |     194|27/6/2018|        10|  Tobias Furtado|      194|      Gláucia Canela|Silver|        2|Bicicleta Altools...|         2|       8280.9|   16561.8| 1159,33|        15402.47|
# |     109| 5/4/2020|        10|  Tobias Furtado|      109|       Deise Meneses|Silver|        2|Bicicleta Altools...|         2|       8280.9|   16561.8|  331,24|        16230.56|
# |     123|18/4/2019|         9|    Simão Rivero|      123|          Dora Rocha|Silver|        1|Bicicleta Aro 29 ...|         2|       7966.8|   15933.6|  956,02|        14977.58|
# |     124|19/4/2019|         5|  Hélio Liberato|      124|Doroteia Quintanilla|Silver|        2|Bicicleta Altools...|         2|      7820.85|   15641.7|  625,67|        15016.03|
# +--------+---------+----------+----------------+---------+--------------------+------+---------+--------------------+----------+-------------+----------+--------+----------------+
# only showing top 10 rows

# %% [markdown]
# #Respondendo algumas perguntas a partir dos dados transformados

# %%
#---------  Qual foi o cliente que menos gastou(comprou) ? ---------# 
#-------------------------------------------------------------------#

ft_vendas_ordenado.select("VendasID","Cliente","ValorTotal").groupBy("Cliente").agg(sum("ValorTotal")).orderBy(desc(sum("ValorTotal"))).show(10)
# Out:
# +--------------------+------------------+
# |             Cliente|   sum(ValorTotal)|
# +--------------------+------------------+
# |    David Carvalhais|29307.480000000003|
# |     Floriano Siebra|28660.300000000003|
# |     Joaquim Hurtado|26852.870000000003|
# |       Adélio Lisboa|          26096.66|
# |     Ibijara Botelho|          25146.85|
# |Godofredo Mascareñas|           22751.4|
# |       Iuri Guterres|          22711.68|
# |   Florinda Assunção|          21471.75|
# |Deolinda Castelbr...|           21357.0|
# |      Belmira Colaço|          21155.46|
# +--------------------+------------------+
# only showing top 10 rows

# %%
#---------  Qual foi o cliente que menos gastou(comprou) ? ---------# 
#-------------------------------------------------------------------#

ft_vendas_ordenado.select("VendasID","Cliente","ValorTotal").groupBy("Cliente").agg(sum("ValorTotal")).orderBy(asc(sum("ValorTotal"))).show(10)
# Out:
# +-------------------+---------------+
# |            Cliente|sum(ValorTotal)|
# +-------------------+---------------+
# |          Cid Pardo|           91.8|
# |Guadalupe Rodrigues|           92.0|
# |         Joana Ataí|           97.2|
# |   Ifigénia Lustosa|          97.75|
# |     Cosme Zambujal|         103.28|
# | Guilhermina Vilaça|          103.5|
# |   Catarina Montero|         114.75|
# |Bartolomeu Vila-Chã|          115.0|
# |      Estela Mattos|         115.06|
# |  Francisca Ramallo|          121.5|
# +-------------------+---------------+
# only showing top 10 rows

# %%
#---------  Qual foi a quantidade total  de produtos vendidos?  ---------# 
#           Qual foi o valor total dos produtos vendidos ?               #
#------------------------------------------------------------------------#

ft_vendas_ordenado.select("ValorTotal","Quantidade").agg(sum("ValorTotal"),sum("Quantidade")).show(10)
# Out:
# +------------------+---------------+
# |   sum(ValorTotal)|sum(Quantidade)|
# +------------------+---------------+
# |1939142.6400000032|            678|
# +------------------+---------------+

# %%
#---------  Qual a quantidade total de clientes ?  ---------#
#           Qual o total de clientes por Status?            #
#-----------------------------------------------------------#

ft_vendas_ordenado.select("ClienteID").agg(countDistinct("ClienteID")).show()
ft_vendas_ordenado.select("ClienteID","Status").groupBy("Status").agg(countDistinct("ClienteID")).show(10)
# Out:
# +----------------+
# |count(ClienteID)|
# +----------------+
# |             250|
# +----------------+
#
# +--------+----------------+
# |  Status|count(ClienteID)|
# +--------+----------------+
# |Platinum|               4|
# |  Silver|             237|
# |    Gold|               9|
# +--------+----------------+

# %%
#---------  Qual foi o vendedor que mais vendeu ?  ---------#
#          Qual o total vendido por cada vendedor?          #
#-----------------------------------------------------------#

ft_vendas_ordenado.select("Vendedor","ValorTotal").groupBy("Vendedor").agg(sum("ValorTotal")).orderBy(desc(sum("ValorTotal"))).show(10)
# Out:
# +----------------+------------------+
# |        Vendedor|   sum(ValorTotal)|
# +----------------+------------------+
# |  Hélio Liberato|386807.99999999994|
# |  Tobias Furtado|282945.06999999995|
# |Jéssica Castelão|277099.43000000017|
# |Capitolino Bahía|228529.01999999996|
# | Godo Capiperibe|         216319.38|
# |    Simão Rivero|         164471.18|
# |   Daniel Pirajá|133423.91999999995|
# |   Iberê Lacerda|          86945.25|
# | Napoleão Méndez| 86614.01000000001|
# |    Armando Lago|          75987.38|
# +----------------+------------------+

# %%
#-------------  Qual foi o produto mais vendido ?  ------------- #
#      Qual foi a quantidade total vendida de cada produto?      #
#----------------------------------------------------------------#

ft_vendas_ordenado.select("ProdutoID","Produto","Quantidade").groupBy("ProdutoID","Produto").agg(sum("Quantidade")).orderBy(desc(sum("Quantidade"))).show(10,truncate=False)
# Out:
# +---------+--------------------------------------------------------------------------------+---------------+
# |ProdutoID|Produto                                                                         |sum(Quantidade)|
# +---------+--------------------------------------------------------------------------------+---------------+
# |10       |Camiseta Predactor 3Xu Multiplied                                               |96             |
# |9        |Bermuda Predactor 3Xu Pro                                                       |81             |
# |8        |Luva De Ciclismo - Gometws Sports                                               |78             |
# |2        |Bicicleta Altools Stroll Aro 26 Freio À Disco 21 Marchas                        |65             |
# |5        |Bicicleta Gometws Endorphine 7.3 - Shimano Alumínio Aro 29 - 24 Marchas         |65             |
# |1        |Bicicleta Aro 29 Mountain Bike Endorphine 6.3 - 24 Marchas - Shimano - Alumínio |63             |
# |3        |Bicicleta Gts Advanced 1.0 Aro 29 Freio Disco Câmbio Traseiro Shimano 24 Marchas|59             |
# |7        |Capacete Gometws Endorphine 2.0                                                 |59             |
# |6        |Bicicleta Gometws Endorphine 6.1 Shimano Alumínio- Aro 26 - 21 Marchas          |57             |
# |4        |Bicicleta Trinc Câmbios Shimano Aro 29 Freio A Disco 24v                        |55             |
# +---------+--------------------------------------------------------------------------------+---------------+

# %% [markdown]
# #Salvando o DataFrame

# %%
#Salvando arquivo em formato parquet e csv
ft_vendas_ordenado.write.format("parquet").save("/FileStore/tables/ft_vendas_process.parquet")
ft_vendas_ordenado.write.format("csv").save("/FileStore/tables/ft_vendas_process.csv")
